# %%
import torch

# %%
x = torch.tensor(2.0, requires_grad=True)

# %%
y = 3*x**2 + 2*x + 1

# %%
print("Forward pass:", y)
# Out:
# Forward pass: tensor(17., grad_fn=<AddBackward0>)

# %%
y.backward()

# %%
print("Gradient:", x.grad)
# Out:
# Gradient: tensor(14.)
