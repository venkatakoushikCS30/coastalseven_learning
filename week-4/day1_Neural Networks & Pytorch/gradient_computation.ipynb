# %%
import torch

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x**2 + 2*x + 1

# %%
y.backward()

# %%
print("x =", x.item())
print("y =", y.item())
print("Gradient (dy/dx) =", x.grad.item())
# Out:
# x = 3.0
# y = 16.0
# Gradient (dy/dx) = 8.0
